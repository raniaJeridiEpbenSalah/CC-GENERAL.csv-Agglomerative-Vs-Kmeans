# %%
import pandas as pd
import numpy as np
df=pd.read_csv("CC GENERAL.csv")
print(df.shape)
df.head()
# Out:
# (8950, 18)
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
df.describe().T
# Out:
#                                    count         mean          std        min  \
# BALANCE                           8950.0  1564.474828  2081.531879   0.000000
# BALANCE_FREQUENCY                 8950.0     0.877271     0.236904   0.000000
# PURCHASES                         8950.0  1003.204834  2136.634782   0.000000
# ONEOFF_PURCHASES                  8950.0   592.437371  1659.887917   0.000000
# INSTALLMENTS_PURCHASES            8950.0   411.067645   904.338115   0.000000
# CASH_ADVANCE                      8950.0   978.871112  2097.163877   0.000000
# PURCHASES_FREQUENCY               8950.0     0.490351     0.401371   0.000000
# ONEOFF_PURCHASES_FREQUENCY        8950.0     0.202458     0.298336   0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY  8950.0     0.364437     0.397448   0.000000
# CASH_ADVANCE_FREQUENCY            8950.0     0.135144     0.200121   0.000000
# CASH_ADVANCE_TRX                  8950.0     3.248827     6.824647   0.000000
# PURCHASES_TRX                     8950.0    14.709832    24.857649   0.000000
# CREDIT_LIMIT                      8949.0  4494.449450  3638.815725  50.000000
# PAYMENTS                          8950.0  1733.143852  2895.063757   0.000000
# MINIMUM_PAYMENTS                  8637.0   864.206542  2372.446607   0.019163
# PRC_FULL_PAYMENT                  8950.0     0.153715     0.292499   0.000000
# TENURE                            8950.0    11.517318     1.338331   6.000000
#
#                                           25%          50%          75%  \
# BALANCE                            128.281915   873.385231  2054.140036
# BALANCE_FREQUENCY                    0.888889     1.000000     1.000000
# PURCHASES                           39.635000   361.280000  1110.130000
# ONEOFF_PURCHASES                     0.000000    38.000000   577.405000
# INSTALLMENTS_PURCHASES               0.000000    89.000000   468.637500
# CASH_ADVANCE                         0.000000     0.000000  1113.821139
# PURCHASES_FREQUENCY                  0.083333     0.500000     0.916667
# ONEOFF_PURCHASES_FREQUENCY           0.000000     0.083333     0.300000
# PURCHASES_INSTALLMENTS_FREQUENCY     0.000000     0.166667     0.750000
# CASH_ADVANCE_FREQUENCY               0.000000     0.000000     0.222222
# CASH_ADVANCE_TRX                     0.000000     0.000000     4.000000
# PURCHASES_TRX                        1.000000     7.000000    17.000000
# CREDIT_LIMIT                      1600.000000  3000.000000  6500.000000
# PAYMENTS                           383.276166   856.901546  1901.134317
# MINIMUM_PAYMENTS                   169.123707   312.343947   825.485459
# PRC_FULL_PAYMENT                     0.000000     0.000000     0.142857
# TENURE                              12.000000    12.000000    12.000000
#
#                                           max
# BALANCE                           19043.13856
# BALANCE_FREQUENCY                     1.00000
# PURCHASES                         49039.57000
# ONEOFF_PURCHASES                  40761.25000
# INSTALLMENTS_PURCHASES            22500.00000
# CASH_ADVANCE                      47137.21176
# PURCHASES_FREQUENCY                   1.00000
# ONEOFF_PURCHASES_FREQUENCY            1.00000
# PURCHASES_INSTALLMENTS_FREQUENCY      1.00000
# CASH_ADVANCE_FREQUENCY                1.50000
# CASH_ADVANCE_TRX                    123.00000
# PURCHASES_TRX                       358.00000
# CREDIT_LIMIT                      30000.00000
# PAYMENTS                          50721.48336
# MINIMUM_PAYMENTS                  76406.20752
# PRC_FULL_PAYMENT                      1.00000
# TENURE                               12.00000

# %%
df=df.drop("CUST_ID", axis=1)
df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)
df.isnull().sum()
df.shape
# Out:
# (8950, 17)

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
plt.figure (figsize = (16, 10))
heatmap = sns.heatmap (df.corr (), vmin = -1, vmax = 1, annot = True, cmap = 'BrBG')

# %%
plt.figure (figsize = (16, 10))
mask = np.triu (np.ones_like (df.corr (), dtype = np.bool))
heatmap = sns.heatmap (df.corr (), mask = mask, vmin = -1, vmax = 1, annot = True, cmap = 'BrBG')

# %%
cor=df.corr()
rf=cor[cor>0.5]
rf
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000                NaN        NaN
# BALANCE_FREQUENCY                      NaN                1.0        NaN
# PURCHASES                              NaN                NaN   1.000000
# ONEOFF_PURCHASES                       NaN                NaN   0.916845
# INSTALLMENTS_PURCHASES                 NaN                NaN   0.679896
# CASH_ADVANCE                           NaN                NaN        NaN
# PURCHASES_FREQUENCY                    NaN                NaN        NaN
# ONEOFF_PURCHASES_FREQUENCY             NaN                NaN        NaN
# PURCHASES_INSTALLMENTS_FREQUENCY       NaN                NaN        NaN
# CASH_ADVANCE_FREQUENCY                 NaN                NaN        NaN
# CASH_ADVANCE_TRX                       NaN                NaN        NaN
# PURCHASES_TRX                          NaN                NaN   0.689561
# CREDIT_LIMIT                      0.531267                NaN        NaN
# PAYMENTS                               NaN                NaN   0.603264
# MINIMUM_PAYMENTS                       NaN                NaN        NaN
# PRC_FULL_PAYMENT                       NaN                NaN        NaN
# TENURE                                 NaN                NaN        NaN
#
#                                   ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  \
# BALANCE                                        NaN                     NaN
# BALANCE_FREQUENCY                              NaN                     NaN
# PURCHASES                                 0.916845                0.679896
# ONEOFF_PURCHASES                          1.000000                     NaN
# INSTALLMENTS_PURCHASES                         NaN                1.000000
# CASH_ADVANCE                                   NaN                     NaN
# PURCHASES_FREQUENCY                            NaN                     NaN
# ONEOFF_PURCHASES_FREQUENCY                0.524891                     NaN
# PURCHASES_INSTALLMENTS_FREQUENCY               NaN                0.511351
# CASH_ADVANCE_FREQUENCY                         NaN                     NaN
# CASH_ADVANCE_TRX                               NaN                     NaN
# PURCHASES_TRX                             0.545523                0.628108
# CREDIT_LIMIT                                   NaN                     NaN
# PAYMENTS                                  0.567292                     NaN
# MINIMUM_PAYMENTS                               NaN                     NaN
# PRC_FULL_PAYMENT                               NaN                     NaN
# TENURE                                         NaN                     NaN
#
#                                   CASH_ADVANCE  PURCHASES_FREQUENCY  \
# BALANCE                                    NaN                  NaN
# BALANCE_FREQUENCY                          NaN                  NaN
# PURCHASES                                  NaN                  NaN
# ONEOFF_PURCHASES                           NaN                  NaN
# INSTALLMENTS_PURCHASES                     NaN                  NaN
# CASH_ADVANCE                          1.000000                  NaN
# PURCHASES_FREQUENCY                        NaN             1.000000
# ONEOFF_PURCHASES_FREQUENCY                 NaN             0.501343
# PURCHASES_INSTALLMENTS_FREQUENCY           NaN             0.862934
# CASH_ADVANCE_FREQUENCY                0.628522                  NaN
# CASH_ADVANCE_TRX                      0.656498                  NaN
# PURCHASES_TRX                              NaN             0.568430
# CREDIT_LIMIT                               NaN                  NaN
# PAYMENTS                                   NaN                  NaN
# MINIMUM_PAYMENTS                           NaN                  NaN
# PRC_FULL_PAYMENT                           NaN                  NaN
# TENURE                                     NaN                  NaN
#
#                                   ONEOFF_PURCHASES_FREQUENCY  \
# BALANCE                                                  NaN
# BALANCE_FREQUENCY                                        NaN
# PURCHASES                                                NaN
# ONEOFF_PURCHASES                                    0.524891
# INSTALLMENTS_PURCHASES                                   NaN
# CASH_ADVANCE                                             NaN
# PURCHASES_FREQUENCY                                 0.501343
# ONEOFF_PURCHASES_FREQUENCY                          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY                         NaN
# CASH_ADVANCE_FREQUENCY                                   NaN
# CASH_ADVANCE_TRX                                         NaN
# PURCHASES_TRX                                       0.544869
# CREDIT_LIMIT                                             NaN
# PAYMENTS                                                 NaN
# MINIMUM_PAYMENTS                                         NaN
# PRC_FULL_PAYMENT                                         NaN
# TENURE                                                   NaN
#
#                                   PURCHASES_INSTALLMENTS_FREQUENCY  \
# BALANCE                                                        NaN
# BALANCE_FREQUENCY                                              NaN
# PURCHASES                                                      NaN
# ONEOFF_PURCHASES                                               NaN
# INSTALLMENTS_PURCHASES                                    0.511351
# CASH_ADVANCE                                                   NaN
# PURCHASES_FREQUENCY                                       0.862934
# ONEOFF_PURCHASES_FREQUENCY                                     NaN
# PURCHASES_INSTALLMENTS_FREQUENCY                          1.000000
# CASH_ADVANCE_FREQUENCY                                         NaN
# CASH_ADVANCE_TRX                                               NaN
# PURCHASES_TRX                                             0.529975
# CREDIT_LIMIT                                                   NaN
# PAYMENTS                                                       NaN
# MINIMUM_PAYMENTS                                               NaN
# PRC_FULL_PAYMENT                                               NaN
# TENURE                                                         NaN
#
#                                   CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# BALANCE                                              NaN               NaN
# BALANCE_FREQUENCY                                    NaN               NaN
# PURCHASES                                            NaN               NaN
# ONEOFF_PURCHASES                                     NaN               NaN
# INSTALLMENTS_PURCHASES                               NaN               NaN
# CASH_ADVANCE                                    0.628522          0.656498
# PURCHASES_FREQUENCY                                  NaN               NaN
# ONEOFF_PURCHASES_FREQUENCY                           NaN               NaN
# PURCHASES_INSTALLMENTS_FREQUENCY                     NaN               NaN
# CASH_ADVANCE_FREQUENCY                          1.000000          0.799561
# CASH_ADVANCE_TRX                                0.799561          1.000000
# PURCHASES_TRX                                        NaN               NaN
# CREDIT_LIMIT                                         NaN               NaN
# PAYMENTS                                             NaN               NaN
# MINIMUM_PAYMENTS                                     NaN               NaN
# PRC_FULL_PAYMENT                                     NaN               NaN
# TENURE                                               NaN               NaN
#
#                                   PURCHASES_TRX  CREDIT_LIMIT  PAYMENTS  \
# BALANCE                                     NaN      0.531267       NaN
# BALANCE_FREQUENCY                           NaN           NaN       NaN
# PURCHASES                              0.689561           NaN  0.603264
# ONEOFF_PURCHASES                       0.545523           NaN  0.567292
# INSTALLMENTS_PURCHASES                 0.628108           NaN       NaN
# CASH_ADVANCE                                NaN           NaN       NaN
# PURCHASES_FREQUENCY                    0.568430           NaN       NaN
# ONEOFF_PURCHASES_FREQUENCY             0.544869           NaN       NaN
# PURCHASES_INSTALLMENTS_FREQUENCY       0.529975           NaN       NaN
# CASH_ADVANCE_FREQUENCY                      NaN           NaN       NaN
# CASH_ADVANCE_TRX                            NaN           NaN       NaN
# PURCHASES_TRX                          1.000000           NaN       NaN
# CREDIT_LIMIT                                NaN      1.000000       NaN
# PAYMENTS                                    NaN           NaN  1.000000
# MINIMUM_PAYMENTS                            NaN           NaN       NaN
# PRC_FULL_PAYMENT                            NaN           NaN       NaN
# TENURE                                      NaN           NaN       NaN
#
#                                   MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# BALANCE                                        NaN               NaN     NaN
# BALANCE_FREQUENCY                              NaN               NaN     NaN
# PURCHASES                                      NaN               NaN     NaN
# ONEOFF_PURCHASES                               NaN               NaN     NaN
# INSTALLMENTS_PURCHASES                         NaN               NaN     NaN
# CASH_ADVANCE                                   NaN               NaN     NaN
# PURCHASES_FREQUENCY                            NaN               NaN     NaN
# ONEOFF_PURCHASES_FREQUENCY                     NaN               NaN     NaN
# PURCHASES_INSTALLMENTS_FREQUENCY               NaN               NaN     NaN
# CASH_ADVANCE_FREQUENCY                         NaN               NaN     NaN
# CASH_ADVANCE_TRX                               NaN               NaN     NaN
# PURCHASES_TRX                                  NaN               NaN     NaN
# CREDIT_LIMIT                                   NaN               NaN     NaN
# PAYMENTS                                       NaN               NaN     NaN
# MINIMUM_PAYMENTS                               1.0               NaN     NaN
# PRC_FULL_PAYMENT                               NaN               1.0     NaN
# TENURE                                         NaN               NaN     1.0

# %%
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.decomposition import PCA
scale = StandardScaler()

copiadata = scale.fit_transform(df)
data = pd.DataFrame(copiadata, columns= df.columns)
# Standardize data
scaler = StandardScaler() 
scaled_df = scaler.fit_transform(df) 
  
# Normalizing the Data 
normalized_df = normalize(scaled_df) 
  
# Converting the numpy array into a pandas DataFrame 
normalized_df = pd.DataFrame(normalized_df) 
  
# Reducing the dimensions of the data 
pca = PCA(n_components = 2) 
data = pca.fit_transform(normalized_df) 
data = pd.DataFrame(data) 
data.columns = ['P1', 'P2'] 
data.head()
# Out:
#          P1        P2
# 0 -0.489826 -0.679677
# 1 -0.518791  0.545016
# 2  0.330885  0.268972
# 3 -0.482374 -0.092107
# 4 -0.563289 -0.481915

# %% [markdown]
# Dimensionality reduction is way to reduce the complexity of a model and avoid overfitting. There are two main categories of dimensionality reduction: feature selection and feature extraction. Via feature selection, we select a subset of the original features, whereas in feature extraction, we derive information from the feature set to construct a new feature subspace.In practice, feature extraction is not only used to improve storage space or the computational efficiency of the learning algorithm, but can also improve the predictive performance by reducing the curse of dimensionality — especially if we are working with non-regularized models.

# %% [markdown]
# Specifically, the Principal Component Analysis (PCA) algorithm is used to compress a dataset onto a lower-dimensional feature subspace with the goal of maintaining most of the relevant information. Principal Component Analysis (PCA) is an unsupervised linear transformation technique that is widely used across different fields, most prominently for feature extraction and dimensionality reduction.In a nutshell, PCA aims to find the directions of maximum variance in high-dimensional data and projects it onto a new subspace with equal or fewer dimensions than the original one.

# %%
#dendrogram
import scipy.cluster.hierarchy as shc
plt.figure(figsize =(10, 10)) 
plt.title('Customer Dendrograms') 
Dendrogram = shc.dendrogram((shc.linkage(data, method ='ward')))

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import AgglomerativeClustering 
silhouette_scores = [] 

for n_cluster in range(2, 8):
    silhouette_scores.append( 
        silhouette_score(data, AgglomerativeClustering(n_clusters = n_cluster).fit_predict(data))) 
    
# Plotting a bar graph to compare the results 
k = [2, 3, 4, 5, 6,7] 
plt.bar(k, silhouette_scores) 
plt.xlabel('Number of clusters', fontsize = 10) 
plt.ylabel('Silhouette Score', fontsize = 10) 
plt.show()

# %%
agg = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='complete')
labels=agg.fit(data)
labels
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=3)

# %%
# Visualizing the clustering 
plt.scatter(data['P1'], data['P2'],  
           c = AgglomerativeClustering(n_clusters = 3).fit_predict(data), cmap =plt.cm.winter) 
plt.show()

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000        864.206542          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
# Visualizing the clustering 
sns.scatterplot(data=normalized_df, x=normalized_df[2], y=normalized_df[3],  
           hue = AgglomerativeClustering(n_clusters = 3).fit_predict(normalized_df)) 
plt.show()

# %%
# Visualizing the clustering 
sns.scatterplot(data=normalized_df, x=normalized_df[6], y=normalized_df[8],  
           hue = AgglomerativeClustering(n_clusters = 3).fit_predict(normalized_df)) 
plt.show()

# %%
agg = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='complete')
agg.fit(data)
# Visualizing the clustering 
plt.scatter(data['P1'], data['P2'],  
           c = AgglomerativeClustering(n_clusters = 4).fit_predict(data), cmap =plt.cm.winter) 
plt.show()

# %%
# Visualizing the clustering 
sns.scatterplot(data=normalized_df, x=normalized_df[2], y=normalized_df[3],  
           hue = AgglomerativeClustering(n_clusters = 4).fit_predict(normalized_df)) 
plt.show()

# %%
# Visualizing the clustering 
sns.scatterplot(data=normalized_df, x=normalized_df[6], y=normalized_df[8],  
           hue = AgglomerativeClustering(n_clusters = 4).fit_predict(normalized_df)) 
plt.show()

# %%
agg = AgglomerativeClustering(n_clusters=7, affinity='euclidean', linkage='complete')
agg.fit(data)
# Visualizing the clustering 
plt.scatter(data['P1'], data['P2'],  
           c = AgglomerativeClustering(n_clusters = 7).fit_predict(data), cmap =plt.cm.winter) 
plt.show()

# %%
# Visualizing the clustering 
sns.scatterplot(data=normalized_df, x=normalized_df[2], y=normalized_df[3],  
           hue = AgglomerativeClustering(n_clusters = 7).fit_predict(normalized_df)) 
plt.show()

# %%
# Visualizing the clustering 
sns.scatterplot(data=normalized_df, x=normalized_df[6], y=normalized_df[8],  
           hue = AgglomerativeClustering(n_clusters = 7).fit_predict(normalized_df)) 
plt.show()

# %%
#Kmeans
from sklearn.cluster import KMeans
sse = {}
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(data)
    sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %%
silhouette_scores = [] 

for n_cluster in range(2, 8):
    silhouette_scores.append( 
        silhouette_score(data, KMeans(n_clusters = n_cluster).fit_predict(data))) 
    
# Plotting a bar graph to compare the results 
k = [2, 3, 4, 5, 6,7] 
plt.bar(k, silhouette_scores) 
plt.xlabel('Number of clusters', fontsize = 10) 
plt.ylabel('Silhouette Score', fontsize = 10) 
plt.show()

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(data)
labels= kmeans.labels_
# Visualizing the clustering 
plt.scatter(data['P1'], data['P2'],  
           c = KMeans(n_clusters = 3).fit_predict(data), cmap =plt.cm.winter) 
plt.show()

# %%
pca= PCA(n_components=2)
X2= pca.fit_transform(data)

# %%
pca_df = pd.DataFrame(data=X2, columns=['pca1','pca2'])
pca_df['labels']= labels
pca_df.head()
# Out:
#        pca1      pca2  labels
# 0 -0.489825 -0.679679       2
# 1 -0.518791  0.545010       1
# 2  0.330885  0.268979       0
# 3 -0.482374 -0.092112       2
# 4 -0.563289 -0.481915       2

# %%
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x='pca1', y='pca2', hue='labels', data=pca_df, palette='bright')

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(data)
labels= kmeans.labels_
# Visualizing the clustering 
plt.scatter(data['P1'], data['P2'],  
           c = KMeans(n_clusters = 4).fit_predict(data), cmap =plt.cm.winter) 
plt.show()

# %%
pca= PCA(n_components=2)
X2= pca.fit_transform(data)
pca_df = pd.DataFrame(data=X2, columns=['pca1','pca2'])
pca_df['labels']= labels
pca_df.head()
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x='pca1', y='pca2', hue='labels', data=pca_df, palette='bright')

# %%
kmeans = KMeans(n_clusters=7)
kmeans.fit(data)
labels= kmeans.labels_
# Visualizing the clustering 
plt.scatter(data['P1'], data['P2'],  
           c = KMeans(n_clusters = 7).fit_predict(data), cmap =plt.cm.winter) 
plt.show()

# %%
pca= PCA(n_components=2)
X2= pca.fit_transform(data)
pca_df = pd.DataFrame(data=X2, columns=['pca1','pca2'])
pca_df['labels']= labels
pca_df.head()
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x='pca1', y='pca2', hue='labels', data=pca_df, palette='bright')
